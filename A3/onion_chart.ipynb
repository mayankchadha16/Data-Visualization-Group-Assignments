# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Electric_Vehicle_Title_and_Registration_Activity.csv")

# %%
len(df)
# Out:
# 855917

# %%
df.head()
# Out:
#   Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  Model Year  \
# 0      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
# 1      Battery Electric Vehicle (BEV)  7SAYGDEE8P       251929492        2023
# 2      Battery Electric Vehicle (BEV)  7SAYGDEE8P       251929492        2023
# 3      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
# 4      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
#
#     Make    Model Vehicle Primary Use  Electric Range  Odometer Reading  \
# 0  TESLA  Model 3           Passenger             308                 0
# 1  TESLA  Model Y           Passenger               0                15
# 2  TESLA  Model Y           Passenger               0                 0
# 3  TESLA  Model 3           Passenger             308                 0
# 4  TESLA  Model 3           Passenger             308                 0
#
#                                        Odometer Code  ...  \
# ...

# %%
len(df.drop_duplicates())
# Out:
# 855897

# %%
make_counts = df.groupby('Make')['DOL Vehicle ID'].nunique()

# %%
make_counts
# Out:
# Make
# ALFA ROMEO                 19
# AUDI                     3716
# AZURE DYNAMICS             11
# BENTLEY                     3
# BMW                      8829
# BUBBLE BUDDY                3
# CADILLAC                  269
# CHEVROLET               16604
# CHRYSLER                 3296
# DODGE                       4
# FIAT                     1125
# FISKER                     58
# FORD                    10515
# GENESIS                   129
# HONDA                    1021
# HYUNDAI                  3937
# JAGUAR                    281
# JEEP                     3961
# KIA                      7853
# LAND ROVER                 56
# LEXUS                     199
# LINCOLN                   256
# LUCID                     216
# MAZDA                     270
# MERCEDES-BENZ            1390
# MINI                      925
# MITSUBISHI               1077
# NISSAN                  22088
# PLYMOUTH                    1
# POLESTAR                  885
# PORSCHE                  1300
# ...

# %%
top_5_makes = make_counts.sort_values(ascending=False).head(5)

# %%
top_5_df = pd.DataFrame({'Make': top_5_makes.index, 'Count of cars': top_5_makes.values})

# %%
top_5_df.head()
# Out:
#         Make  Count of cars
# 0      TESLA          84760
# 1     NISSAN          22088
# 2  CHEVROLET          16604
# 3       FORD          10515
# 4        BMW           8829

# %%
top_5_df.to_csv('top_5_makes.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /mnt/e/IIITB/Semester 7/dv/Assignment/Data-Visualization-Group-Assignments/a3/onion_chart.ipynb Cell 10 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/e/IIITB/Semester%207/dv/Assignment/Data-Visualization-Group-Assignments/a3/onion_chart.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> top_5_df.to_csv('top_5_makes.csv', index=False)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
# ...

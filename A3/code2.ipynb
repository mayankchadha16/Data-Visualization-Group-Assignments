# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Electric_Vehicle_Title_and_Registration_Activity.csv")

# %%
df.head()
# Out:
#   Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  Model Year  \
# 0      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
# 1      Battery Electric Vehicle (BEV)  7SAYGDEE8P       251929492        2023
# 2      Battery Electric Vehicle (BEV)  7SAYGDEE8P       251929492        2023
# 3      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
# 4      Battery Electric Vehicle (BEV)  5YJ3E1EC6L         1981598        2020
#
#     Make    Model Vehicle Primary Use  Electric Range  Odometer Reading  \
# 0  TESLA  Model 3           Passenger             308                 0
# 1  TESLA  Model Y           Passenger               0                15
# 2  TESLA  Model Y           Passenger               0                 0
# 3  TESLA  Model 3           Passenger             308                 0
# 4  TESLA  Model 3           Passenger             308                 0
#
#                                        Odometer Code  ...  \
# 0  Odometer reading is not collected at time of r...  ...
# 1                                     Actual Mileage  ...
# 2  Odometer reading is not collected at time of r...  ...
# 3  Odometer reading is not collected at time of r...  ...
# 4  Odometer reading is not collected at time of r...  ...
#
#   Meets 2019 HB 2042 Sale Price/Value Requirement  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    2019 HB 2042: Battery Range Requirement  \
# 0                                      NaN
# 1                         No battery range
# 2                         No battery range
# 3                                      NaN
# 4                                      NaN
#
#   2019 HB 2042: Purchase Date Requirement  \
# 0      Non-sale, registration transaction
# 1         Meets purchase date requirement
# 2      Non-sale, registration transaction
# 3      Non-sale, registration transaction
# 4      Non-sale, registration transaction
#
#    2019 HB 2042: Sale Price/Value Requirement Electric Vehicle Fee Paid  \
# 0          Non-sale, registration transaction                        No
# 1                         Sale price too high            Not Applicable
# 2          Non-sale, registration transaction                        No
# 3          Non-sale, registration transaction                       Yes
# 4          Non-sale, registration transaction                       Yes
#
#   Transportation Electrification Fee Paid  \
# 0                                      No
# 1                          Not Applicable
# 2                                      No
# 3                                     Yes
# 4                                     Yes
#
#    Hybrid Vehicle Electrification Fee Paid 2020 Census Tract  \
# 0                                       No      5.303302e+10
# 1                           Not Applicable      5.303302e+10
# 2                                       No      5.303302e+10
# 3                                       No      5.303302e+10
# 4                                       No      5.303302e+10
#
#   Legislative District                               Electric Utility
# 0                 45.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 1                 45.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2                 45.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 3                 45.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 4                 45.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
# [5 rows x 35 columns]

# %%
len(df)
# Out:
# 855917

# %%
df = df[df["Base MSRP"] != 0]

# %%
len(df)
# Out:
# 39808

# %%
df = df[df["Electric Range"] != 0]

# %%
# df = df[df["Sale Price"] != 0]

# %%
len(df)
# Out:
# 39808

# %%
df =df.drop(['VIN (1-10)', 'Postal Code', '2020 Census Tract'], axis=1)

# %%
# plotting correlation heatmap 
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True) 
  
# displaying heatmap 
plt.show()

# %%
df1=df.select_dtypes(exclude=['object'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.boxplot(data=df1, x=column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/e/IIITB/Semester 7/dv/Assignment/Data-Visualization-Group-Assignments/a3/code2.ipynb Cell 11 line <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/e/IIITB/Semester%207/dv/Assignment/Data-Visualization-Group-Assignments/a3/code2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for column in df1:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/e/IIITB/Semester%207/dv/Assignment/Data-Visualization-Group-Assignments/a3/code2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         plt.figure(figsize=(17,1))
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/e/IIITB/Semester%207/dv/Assignment/Data-Visualization-Group-Assignments/a3/code2.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         sns.boxplot(data=df1, x=column)
#
# File /usr/lib/python3/dist-packages/seaborn/categorical.py:2247, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2244     ax = plt.gca()
#    2245 kwargs.update(dict(whis=whis))
# -> 2247 plotter.plot(ax, kwargs)
#    2248 return ax
#
# File /usr/lib/python3/dist-packages/seaborn/categorical.py:546, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     544 def plot(self, ax, boxplot_kws):
#     545     """Make the plot."""
# --> 546     self.draw_boxplot(ax, boxplot_kws)
#     547     self.annotate_axes(ax)
#     548     if self.orient == "h":
#
# File /usr/lib/python3/dist-packages/seaborn/categorical.py:478, in _BoxPlotter.draw_boxplot(self, ax, kws)
#     475 if box_data.size == 0:
#     476     continue
# --> 478 artist_dict = ax.boxplot(box_data,
#     479                          vert=vert,
#     480                          patch_artist=True,
#     481                          positions=[i],
#     482                          widths=self.width,
#     483                          **kws)
#     484 color = self.colors[i]
#     485 self.restyle_boxplot(artist_dict, color, props)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:3710, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3707 if bootstrap is None:
#    3708     bootstrap = rcParams['boxplot.bootstrap']
# -> 3710 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3711                                labels=labels, autorange=autorange)
#    3712 if notch is None:
#    3713     notch = rcParams['boxplot.notch']
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1198, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1195 stats['mean'] = np.mean(x)
#    1197 # medians and quartiles
# -> 1198 q1, med, q3 = np.percentile(x, [25, 50, 75])
#    1200 # interquartile range
#    1201 stats['iqr'] = q3 - q1
#
# File <__array_function__ internals>:180, in percentile(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:4134, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4132 if not _quantile_is_valid(q):
#    4133     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4134 return _quantile_unchecked(
#    4135     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:4383, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4375 def _quantile_unchecked(a,
#    4376                         q,
#    4377                         axis=None,
#    (...)
#    4380                         method="linear",
#    4381                         keepdims=False):
#    4382     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4383     r, k = _ureduce(a,
#    4384                     func=_quantile_ureduce_func,
#    4385                     q=q,
#    4386                     axis=axis,
#    4387                     out=out,
#    4388                     overwrite_input=overwrite_input,
#    4389                     method=method)
#    4390     if keepdims:
#    4391         return r.reshape(q.shape + k)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:3702, in _ureduce(a, func, **kwargs)
#    3699 else:
#    3700     keepdim = (1,) * a.ndim
# -> 3702 r = func(a, **kwargs)
#    3703 return r, keepdim
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:4552, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4550     else:
#    4551         arr = a.copy()
# -> 4552 result = _quantile(arr,
#    4553                    quantiles=q,
#    4554                    axis=axis,
#    4555                    method=method,
#    4556                    out=out)
#    4557 return result
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:4669, in _quantile(arr, quantiles, axis, method, out)
#    4667     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4668     gamma = gamma.reshape(result_shape)
# -> 4669     result = _lerp(previous,
#    4670                    next,
#    4671                    gamma,
#    4672                    out=out)
#    4673 if np.any(slices_having_nans):
#    4674     if result.ndim == 0 and out is None:
#    4675         # can't write to a scalar
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:4486, in _lerp(a, b, t, out)
#    4472 def _lerp(a, b, t, out=None):
#    4473     """
#    4474     Compute the linear interpolation weighted by gamma on each point of
#    4475     two same shape array.
#    (...)
#    4484         Output array.
#    4485     """
# -> 4486     diff_b_a = subtract(b, a)
#    4487     # asanyarray is a stop-gap until gh-13105
#    4488     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

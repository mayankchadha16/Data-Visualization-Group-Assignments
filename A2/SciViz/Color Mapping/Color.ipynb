# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('./output.csv')

# %%
len(df.index)
# Out:
# 1036800

# %%
df = df[df.Value != -999]

# %%
len(df.index)
# Out:
# 17228

# %%
# Sample data (replace with your latitude, longitude, and values)
latitudes = df['Latitude'].tolist()
longitudes = df['Longitude'].tolist()
values = df['Value'].tolist()

# %%
latitudes[0]
# Out:
# -60.375

# %%
import geopandas as gpd

# %%
df['Value'].unique()
# Out:
# array([0.        , 0.7082493 , 0.00099964, ..., 0.01149858, 0.06399858,
#        0.05049929])

# %%
# df['Value'] = df['Value'].astype(int)

# %%
df['Value'].unique()
# Out:
# array([0.        , 0.7082493 , 0.00099964, ..., 0.01149858, 0.06399858,
#        0.05049929])

# %% [markdown]
# Sequential: Continuous

# %%
fig, ax = plt.subplots(figsize=(8,6))

countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries.plot(color="lightgrey", ax=ax)

df.plot(x="Longitude", y="Latitude", kind="scatter", 
        c="Value", colormap="Purples", 
        ax=ax)

plt.show()
# Out:
# /tmp/ipykernel_77795/634526503.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %% [markdown]
# Diverging

# %%
fig, ax = plt.subplots(figsize=(8,6))

countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries.plot(color="lightgrey", ax=ax)

df.plot(x="Longitude", y="Latitude", kind="scatter", 
        c="Value", colormap="coolwarm", 
        ax=ax)

plt.show()
# Out:
# /tmp/ipykernel_77795/2640354666.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
# Discrete tab10

fig, ax = plt.subplots(figsize=(8,6))

countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries.plot(color="lightgrey", ax=ax)

df.plot(x="Longitude", y="Latitude", kind="scatter", 
        c="Value", colormap="Accent", 
        ax=ax)

plt.show()
# Out:
# /tmp/ipykernel_77795/3380876104.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
